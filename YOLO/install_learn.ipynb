# %% [markdown]
# # 这个笔记记录安装和学习YOLO模型的一些知识和指令

# %% [markdown]
# YOLO 官方网站
#
# https://docs.ultralytics.com/zh/
#
# 项目提供了 pyproject.toml 文件
# 用来管理和配置python项目
#
# **如何使用pyprojject.toml 文件**
#
# 常见的构建工具 Poetry 和Setuptools
#
# Poetry 现代的包管理和项目构建工具、
# 安装 Poetry

# %%
sudo apt install python3-poetry

# 在终端运行指令前要doublecheck

# %% [markdown]
# 之后git 克隆 YOLO到本地
#
# cd 进入 YOLO/ultralytics 文件夹
#
# 配置环境

# %%
pip install

# %% [markdown]
# 有提醒是否创建独立环境，选择是后，选择安装的依赖
#
# ![image.png](attachment:image.png)\
# 继续选择依赖\
# ![image-2.png](attachment:image-2.png)\
# 自动创建虚拟环境\
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 环境搭建好后，运行案例
